# %% [markdown]
# <a href="https://colab.research.google.com/github/haneeth25/Libraries_prac/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
# data to display on plots
x = [3, 1, 3,4,1]
y = [3, 2, 1,2,3]

# This will plot a simple line chart
# with elements of x as x axis and y
# as y axis
plt.plot(x, y)
plt.title("Line Chart")

# Adding the legends
plt.legend(["Line"])
plt.show()

# %%
# importing libraries
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0.1, 2 * np.pi, 41)
y = np.exp(np.sin(x))

plt.stem(x, y, use_line_collection = True)
plt.show()
# Out:
# <ipython-input-4-e441590afae1>:8: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(x, y, use_line_collection = True)

# %%
x
# Out:
# array([0.1       , 0.25457963, 0.40915927, 0.5637389 , 0.71831853,
#        0.87289816, 1.0274778 , 1.18205743, 1.33663706, 1.49121669,
#        1.64579633, 1.80037596, 1.95495559, 2.10953522, 2.26411486,
#        2.41869449, 2.57327412, 2.72785376, 2.88243339, 3.03701302,
#        3.19159265, 3.34617229, 3.50075192, 3.65533155, 3.80991118,
#        3.96449082, 4.11907045, 4.27365008, 4.42822972, 4.58280935,
#        4.73738898, 4.89196861, 5.04654825, 5.20112788, 5.35570751,
#        5.51028714, 5.66486678, 5.81944641, 5.97402604, 6.12860567,
#        6.28318531])

# %%
import matplotlib.pyplot as plt
# data to display on plots
x = [3, 1, 3, 12, 2, 4, 4]
y = [3, 2, 1, 4, 5, 6, 7]

# This will plot a simple bar chart
plt.bar(x, y)

# Title to the plot
plt.title("Bar Chart")

# Adding the legends
plt.legend(["bar"])
plt.show()

# %%
marks = [90,50,40,60,55,44,30,10,34,84]
grade_intervals = [0,35,70,100]
plt.hist(marks,grade_intervals)
# Out:
# (array([3., 5., 2.]),
#  array([  0.,  35.,  70., 100.]),
#  <BarContainer object of 3 artists>)

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #Scatter Plot

# %%
x_data = np.random.random(50)*100
y_data = np.random.random(50)*100

# %%
plt.scatter(x_data,y_data,c='blue',marker = '*',s=150)
plt.show()

# %%
x_data = np.random.random(1000)*100
y_data = np.random.random(1000)*100

# %%
plt.scatter(x_data,y_data,c='blue',marker = '*',s=150,alpha=0.3)
plt.show()

# %% [markdown]
# # Line chart

# %%
#Line chart
# example to views progress of weight of a person
years = [2006 + x for x in range(16)]
weights = [80,83,84,85,86,89,87,91,90,93,94,90,96,97,93,99]
plt.plot(years,weights)

# %%
#lw - line width
#ls - line style
plt.plot(years,weights,color='red',lw=3,ls='--')

# %% [markdown]
# #Bar Plot

# %%
# Survey how many of them like programing language
x = ['c++','c#','python','java','go','python']
y = [10,30,20,40,10,10]
plt.bar(x,y,color='red',align='edge',width = 0.5,edgecolor='green')
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# #Histogram

# %%
import numpy as np

# %%
ages = np.random.normal(20,1.5,1000)

# %%
plt.hist(ages,edgecolor='black')
# Out:
# (array([  7.,  29.,  82., 153., 229., 223., 142.,  96.,  34.,   5.]),
#  array([15.56597582, 16.44871334, 17.33145086, 18.21418838, 19.0969259 ,
#         19.97966342, 20.86240093, 21.74513845, 22.62787597, 23.51061349,
#         24.39335101]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(ages,edgecolor='black',cumulative=True)
# Out:
# (array([   7.,   36.,  118.,  271.,  500.,  723.,  865.,  961.,  995.,
#         1000.]),
#  array([15.56597582, 16.44871334, 17.33145086, 18.21418838, 19.0969259 ,
#         19.97966342, 20.86240093, 21.74513845, 22.62787597, 23.51061349,
#         24.39335101]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # piecharts

# %%
lang = ['c++','c#','python','java','go']
votes = [10,30,20,40,10]
plt.pie(votes,labels = lang)
plt.show()

# %%
explodes = [0.1,0,0,0.1,0]

# %%
plt.pie(votes,labels = lang,explode=explodes)
plt.show()

# %%
plt.pie(votes,labels = lang,explode=explodes,autopct = '%.2f%%',pctdistance=0.8)
plt.show()

# %%
plt.pie(votes,labels = lang,explode=explodes,autopct = '%.2f%%',pctdistance=0.8,startangle=90)
plt.show()

# %% [markdown]
# #Boxplot

# %%
heights = np.random.normal(172,8,300)

# %%
plt.boxplot(heights)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x789b042744f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x789b04275d80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x789b04276770>],
#  'medians': [<matplotlib.lines.Line2D at 0x789b04274100>],
#  'fliers': [<matplotlib.lines.Line2D at 0x789b042775e0>],
#  'means': []}

# %%
first = np.linspace(0,10,25)
second = np.linspace(10,200,25)
third = np.linspace(200,210,25)
fourth = np.linspace(210,230,25)
data = np.concatenate((first,second,third,fourth))

plt.boxplot(data)
plt.show()

# %% [markdown]
# #Plot Customization

# %%
years = [2014+x for x in range(8)]
years
# Out:
# [2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]

# %%
income = [55,56,62,61,72,72,73,75]
income_ticks = list(range(50,81,2))

# %%
plt.plot(years,income)
#title
plt.title('income of jhon (in usd)',fontsize = 30)
#xlabel
plt.xlabel('years')
#ylabel
plt.ylabel('yearly income(in usd)')
#to make y_axis into 55.0K usd instead of just showing 55.0
plt.yticks(income_ticks,[f"{x}k usd" for x in income_ticks])
#Similary we can do for x axis
plt.xticks(years,[f"{x}yy" for x in years],rotation = 45)
plt.show()

# %% [markdown]
# #Legends and multiple plots
